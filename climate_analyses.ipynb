# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

from scipy import stats

# %%
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
matplotlib.rcParams['figure.dpi'] = 150

# %% [markdown]
# #### Motivation for choosing selected counties in KS and WA
# Metric: Payment indemnity ($)
# Dates: 1989 - 2018
# Commodity: all commodities
# Cause of loss: all causes

# %%
# Kansas (KS)
df = pd.DataFrame(reversed(sorted([64130444, 67549469, 66356433, 57019616, 59743536])))
labels = np.array(["Grant", "Morton", "Kearny", "Gray", "Haskell"]).reshape(5,1)
sns.heatmap(df, annot=labels, fmt='', cmap='Blues', vmin=0.15e8, vmax=1.6e8, xticklabels=False, yticklabels=False)
plt.title("Indemnity (KS)")
plt.show() # not a gradient

# Washington (WA)
cmap = sns.cm.rocket_r
df = pd.DataFrame(reversed(sorted([151913200, 1985296, 1610478, 41324924, 136160264])))
labels = np.array(["Whitman", "Lincoln", "Spokane", "Okanogan", "Skagit"]).reshape(5,1)
#labels = np.array(reversed(["Skagit", "Okanogan", "Spokane", "Lincoln", "Whitman"])).reshape(5,1)
sns.heatmap(df, annot=labels, fmt='', cmap='Blues', vmin=0.15e8, vmax=1.6e8, xticklabels=False, yticklabels=False)
plt.title("Indemnity (WA)")
plt.show() # gradient

# %% [markdown]
# ### Washington (WA) — Lincoln, Okanogan, Skagit, Spokane, Whitman

# %% [markdown]
# #### Avg_Temp (average temperature)

# %%
# Lincoln (avg_temp)
df_avg_temp_Lincoln = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Lincoln_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Lincoln.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Lincoln['Year'] = df_avg_temp_Lincoln['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Lincoln['Month'] = df_avg_temp_Lincoln['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Lincoln = df_avg_temp_Lincoln.drop(['Date'], axis=1)

# Okanogan (avg_temp)
df_avg_temp_Okanogan = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Okanogan_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Okanogan.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Okanogan['Year'] = df_avg_temp_Okanogan['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Okanogan['Month'] = df_avg_temp_Okanogan['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Okanogan = df_avg_temp_Okanogan.drop(['Date'], axis=1)

# Skagit (avg_temp)
df_avg_temp_Skagit = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Skagit_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Skagit.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Skagit['Year'] = df_avg_temp_Skagit['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Skagit['Month'] = df_avg_temp_Skagit['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Skagit = df_avg_temp_Skagit.drop(['Date'], axis=1)

# Spokane (avg_temp)
df_avg_temp_Spokane = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Spokane_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Spokane.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Spokane['Year'] = df_avg_temp_Spokane['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Spokane['Month'] = df_avg_temp_Spokane['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Spokane = df_avg_temp_Spokane.drop(['Date'], axis=1)

# Whitman (avg_temp)
df_avg_temp_Whitman = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Whitman_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Whitman.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Whitman['Year'] = df_avg_temp_Whitman['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Whitman['Month'] = df_avg_temp_Whitman['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Whitman = df_avg_temp_Whitman.drop(['Date'], axis=1)

# Testing (avg_temp)
#df_avg_temp_Lincoln.head()

# %% [markdown]
# #### Min_Temp (minimum temperature)

# %%
# Lincoln (min_temp)
df_min_temp_Lincoln = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Lincoln_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Lincoln.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Lincoln['Year'] = df_min_temp_Lincoln['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Lincoln['Month'] = df_min_temp_Lincoln['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Lincoln = df_min_temp_Lincoln.drop(['Date'], axis=1)

# Okanogan (min_temp)
df_min_temp_Okanogan = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Okanogan_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Okanogan.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Okanogan['Year'] = df_min_temp_Okanogan['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Okanogan['Month'] = df_min_temp_Okanogan['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Okanogan = df_min_temp_Okanogan.drop(['Date'], axis=1)

# Skagit (min_temp)
df_min_temp_Skagit = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Skagit_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Skagit.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Skagit['Year'] = df_min_temp_Skagit['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Skagit['Month'] = df_min_temp_Skagit['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Skagit = df_min_temp_Skagit.drop(['Date'], axis=1)

# Spokane (min_temp)
df_min_temp_Spokane = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Spokane_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Spokane.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Spokane['Year'] = df_min_temp_Spokane['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Spokane['Month'] = df_min_temp_Spokane['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Spokane = df_min_temp_Spokane.drop(['Date'], axis=1)

# Whitman (min_temp)
df_min_temp_Whitman = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Whitman_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Whitman.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Whitman['Year'] = df_min_temp_Whitman['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Whitman['Month'] = df_min_temp_Whitman['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Whitman = df_min_temp_Whitman.drop(['Date'], axis=1)

# Testing (min_temp)
#df_min_temp_Okanogan.head()

# %% [markdown]
# #### Max_Temp (minimum temperature)

# %%
# Lincoln (max_temp)
df_max_temp_Lincoln = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Lincoln_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Lincoln.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Lincoln['Year'] = df_max_temp_Lincoln['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Lincoln['Month'] = df_max_temp_Lincoln['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Lincoln = df_max_temp_Lincoln.drop(['Date'], axis=1)

# Okanogan (max_temp)
df_max_temp_Okanogan = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Okanogan_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Okanogan.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Okanogan['Year'] = df_max_temp_Okanogan['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Okanogan['Month'] = df_max_temp_Okanogan['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Okanogan = df_max_temp_Okanogan.drop(['Date'], axis=1)

# Skagit (max_temp)
df_max_temp_Skagit = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Skagit_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Skagit.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Skagit['Year'] = df_max_temp_Skagit['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Skagit['Month'] = df_max_temp_Skagit['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Skagit = df_max_temp_Skagit.drop(['Date'], axis=1)

# Spokane (max_temp)
df_max_temp_Spokane = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Spokane_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Spokane.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Spokane['Year'] = df_max_temp_Spokane['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Spokane['Month'] = df_max_temp_Spokane['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Spokane = df_max_temp_Spokane.drop(['Date'], axis=1)

# Whitman (max_temp)
df_max_temp_Whitman = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Whitman_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Whitman.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Whitman['Year'] = df_max_temp_Whitman['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Whitman['Month'] = df_max_temp_Whitman['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Whitman = df_max_temp_Whitman.drop(['Date'], axis=1)

# Testing (max_temp)
#df_max_temp_Whitman.head()

# %% [markdown]
# #### Precipitation

# %%
# Lincoln (precipitation)
df_precipitation_Lincoln = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Lincoln_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Lincoln.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Lincoln['Year'] = df_precipitation_Lincoln['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Lincoln['Month'] = df_precipitation_Lincoln['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Lincoln = df_precipitation_Lincoln.drop(['Date'], axis=1)

# Okanogan (precipitation)
df_precipitation_Okanogan = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Okanogan_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Okanogan.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Okanogan['Year'] = df_precipitation_Okanogan['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Okanogan['Month'] = df_precipitation_Okanogan['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Okanogan = df_precipitation_Okanogan.drop(['Date'], axis=1)

# Skagit (precipitation)
df_precipitation_Skagit = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Skagit_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Skagit.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Skagit['Year'] = df_precipitation_Skagit['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Skagit['Month'] = df_precipitation_Skagit['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Skagit = df_precipitation_Skagit.drop(['Date'], axis=1)

# Spokane (precipitation)
df_precipitation_Spokane = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Spokane_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Spokane.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Spokane['Year'] = df_precipitation_Spokane['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Spokane['Month'] = df_precipitation_Spokane['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Spokane = df_precipitation_Spokane.drop(['Date'], axis=1)

# Whitman (precipitation)
df_precipitation_Whitman = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_Whitman_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Whitman.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Whitman['Year'] = df_precipitation_Whitman['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Whitman['Month'] = df_precipitation_Whitman['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Whitman = df_precipitation_Whitman.drop(['Date'], axis=1)

# Testing (precipitation)
#df_precipitation_Spokane.head()

# %% [markdown]
# #### Drought (PDSI)

# %%
df_drought_WA = pd.read_csv("Data_KS_WA/WA/WA_Climate/WA_PDSI.csv", skiprows=3).drop(['Anomaly'], axis=1)
df_drought_WA.rename(columns={'Value':'PDSI'}, inplace=True)
df_drought_WA['Year'] = df_drought_WA['Date'].apply(lambda x: int(str(x)[:4]))
df_drought_WA['Month'] = df_drought_WA['Date'].apply(lambda x: int(str(x)[-2:]))
df_drought_WA = df_drought_WA.drop(['Date'], axis=1)

# Testing (drought)
#df_drought_WA.head()

# %% [markdown]
# #### Adding climate data to Cause_of_Loss datasets (by county for WA)

# %%
# Lincoln
df_loss_Lincoln = pd.read_csv("Data_KS_WA/WA/WA_Cause_of_Loss/WA_Lincoln_Cause_of_Loss.csv") 
df_loss_Lincoln.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Lincoln['Year'] = pd.to_numeric(df_loss_Lincoln['Year'], downcast='integer')
df_loss_Lincoln['Month'] = pd.to_numeric(df_loss_Lincoln['Month'], downcast='integer')
df_loss_Lincoln_merged = pd.merge(df_loss_Lincoln, df_avg_temp_Lincoln, how='left', on=['Year', 'Month'])
df_loss_Lincoln_merged = pd.merge(df_loss_Lincoln_merged, df_min_temp_Lincoln, how='left', on=['Year', 'Month'])
df_loss_Lincoln_merged = pd.merge(df_loss_Lincoln_merged, df_max_temp_Lincoln, how='left', on=['Year', 'Month'])
df_loss_Lincoln_merged = pd.merge(df_loss_Lincoln_merged, df_precipitation_Lincoln, how='left', on=['Year', 'Month'])
df_loss_Lincoln_merged = pd.merge(df_loss_Lincoln_merged, df_drought_WA, how='left', on=['Year', 'Month'])

# Okanogan
df_loss_Okanogan = pd.read_csv("Data_KS_WA/WA/WA_Cause_of_Loss/WA_Okanogan_Cause_of_Loss.csv") 
#df_loss_Okanogan.Month.replace({"Unspecified": 0}, inplace=True) # not needed
df_loss_Okanogan['Year'] = pd.to_numeric(df_loss_Okanogan['Year'], downcast='integer')
df_loss_Okanogan['Month'] = pd.to_numeric(df_loss_Okanogan['Month'], downcast='integer')
df_loss_Okanogan_merged = pd.merge(df_loss_Okanogan, df_avg_temp_Okanogan, how='left', on=['Year', 'Month'])
df_loss_Okanogan_merged = pd.merge(df_loss_Okanogan_merged, df_min_temp_Okanogan, how='left', on=['Year', 'Month'])
df_loss_Okanogan_merged = pd.merge(df_loss_Okanogan_merged, df_max_temp_Okanogan, how='left', on=['Year', 'Month'])
df_loss_Okanogan_merged = pd.merge(df_loss_Okanogan_merged, df_precipitation_Okanogan, how='left', on=['Year', 'Month'])
df_loss_Okanogan_merged = pd.merge(df_loss_Okanogan_merged, df_drought_WA, how='left', on=['Year', 'Month'])

# Skagit
df_loss_Skagit = pd.read_csv("Data_KS_WA/WA/WA_Cause_of_Loss/WA_Skagit_Cause_of_Loss.csv") 
#df_loss_Skagit.Month.replace({"Unspecified": 0}, inplace=True) # not needed
df_loss_Skagit['Year'] = pd.to_numeric(df_loss_Skagit['Year'], downcast='integer')
df_loss_Skagit['Month'] = pd.to_numeric(df_loss_Skagit['Month'], downcast='integer')
df_loss_Skagit_merged = pd.merge(df_loss_Skagit, df_avg_temp_Skagit, how='left', on=['Year', 'Month'])
df_loss_Skagit_merged = pd.merge(df_loss_Skagit_merged, df_min_temp_Skagit, how='left', on=['Year', 'Month'])
df_loss_Skagit_merged = pd.merge(df_loss_Skagit_merged, df_max_temp_Skagit, how='left', on=['Year', 'Month'])
df_loss_Skagit_merged = pd.merge(df_loss_Skagit_merged, df_precipitation_Skagit, how='left', on=['Year', 'Month'])
df_loss_Skagit_merged = pd.merge(df_loss_Skagit_merged, df_drought_WA, how='left', on=['Year', 'Month'])

# Spokane
df_loss_Spokane = pd.read_csv("Data_KS_WA/WA/WA_Cause_of_Loss/WA_Spokane_Cause_of_Loss.csv") 
df_loss_Spokane.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Spokane['Year'] = pd.to_numeric(df_loss_Spokane['Year'], downcast='integer')
df_loss_Spokane['Month'] = pd.to_numeric(df_loss_Spokane['Month'], downcast='integer')
df_loss_Spokane_merged = pd.merge(df_loss_Spokane, df_avg_temp_Spokane, how='left', on=['Year', 'Month'])
df_loss_Spokane_merged = pd.merge(df_loss_Spokane_merged, df_min_temp_Spokane, how='left', on=['Year', 'Month'])
df_loss_Spokane_merged = pd.merge(df_loss_Spokane_merged, df_max_temp_Spokane, how='left', on=['Year', 'Month'])
df_loss_Spokane_merged = pd.merge(df_loss_Spokane_merged, df_precipitation_Spokane, how='left', on=['Year', 'Month'])
df_loss_Spokane_merged = pd.merge(df_loss_Spokane_merged, df_drought_WA, how='left', on=['Year', 'Month'])

# Whitman
df_loss_Whitman = pd.read_csv("Data_KS_WA/WA/WA_Cause_of_Loss/WA_Whitman_Cause_of_Loss.csv") 
df_loss_Whitman.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Whitman['Year'] = pd.to_numeric(df_loss_Whitman['Year'], downcast='integer')
df_loss_Whitman['Month'] = pd.to_numeric(df_loss_Whitman['Month'], downcast='integer')
df_loss_Whitman_merged = pd.merge(df_loss_Whitman, df_avg_temp_Whitman, how='left', on=['Year', 'Month'])
df_loss_Whitman_merged = pd.merge(df_loss_Whitman_merged, df_min_temp_Whitman, how='left', on=['Year', 'Month'])
df_loss_Whitman_merged = pd.merge(df_loss_Whitman_merged, df_max_temp_Whitman, how='left', on=['Year', 'Month'])
df_loss_Whitman_merged = pd.merge(df_loss_Whitman_merged, df_precipitation_Whitman, how='left', on=['Year', 'Month'])
df_loss_Whitman_merged = pd.merge(df_loss_Whitman_merged, df_drought_WA, how='left', on=['Year', 'Month'])

# Testing
df_loss_Whitman_merged.head(10)
# Out:
#    State  State name  County County name  Year  Month  \
# 0     53  Washington      75     Whitman  1989      0
# 1     53  Washington      75     Whitman  1989      0
# 2     53  Washington      75     Whitman  1989      0
# 3     53  Washington      75     Whitman  1989      0
# 4     53  Washington      75     Whitman  1989      2
# 5     53  Washington      75     Whitman  1989      2
# 6     53  Washington      75     Whitman  1989      2
# 7     53  Washington      75     Whitman  1989      2
# 8     53  Washington      75     Whitman  1989      2
# 9     53  Washington      75     Whitman  1989      4
#
#   Commodity (partial list)                Cause of loss  \
# 0                    Wheat                  Cold Winter
# 1                    Wheat                      Drought
# 2                    Wheat  Excess Moisture/precip/rain
# 3                    Wheat                       Freeze
# 4                    Wheat             Cold Wet Weather
# ...

# %% [markdown]
# #### Combining modified Cause_of_Loss datasets (all counties in WA)

# %%
frames_WA = [df_loss_Lincoln_merged, df_loss_Okanogan_merged, df_loss_Skagit_merged, df_loss_Spokane_merged, df_loss_Whitman_merged]
df_loss_WA = pd.concat(frames_WA) # contains all WA counties
#print(df_loss_WA)

# %% [markdown]
# ### Kansas (KS) — Grant, Gray, Haskell, Kearny, Morton

# %% [markdown]
# #### Avg_Temp (average temperature)

# %%
# Grant (avg_temp)
df_avg_temp_Grant = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Grant_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Grant.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Grant['Year'] = df_avg_temp_Grant['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Grant['Month'] = df_avg_temp_Grant['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Grant = df_avg_temp_Grant.drop(['Date'], axis=1)

# Gray (avg_temp)
df_avg_temp_Gray = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Gray_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Gray.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Gray['Year'] = df_avg_temp_Gray['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Gray['Month'] = df_avg_temp_Gray['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Gray = df_avg_temp_Gray.drop(['Date'], axis=1)

# Haskell (avg_temp)
df_avg_temp_Haskell = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Haskell_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Haskell.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Haskell['Year'] = df_avg_temp_Haskell['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Haskell['Month'] = df_avg_temp_Haskell['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Haskell = df_avg_temp_Haskell.drop(['Date'], axis=1)

# Kearny (avg_temp)
df_avg_temp_Kearny = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Kearny_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Kearny.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Kearny['Year'] = df_avg_temp_Kearny['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Kearny['Month'] = df_avg_temp_Kearny['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Kearny = df_avg_temp_Kearny.drop(['Date'], axis=1)

# Morton (avg_temp)
df_avg_temp_Morton = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Morton_Avg_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_avg_temp_Morton.rename(columns={'Value':'Avg_Temp'}, inplace=True)
df_avg_temp_Morton['Year'] = df_avg_temp_Morton['Date'].apply(lambda x: int(str(x)[:4]))
df_avg_temp_Morton['Month'] = df_avg_temp_Morton['Date'].apply(lambda x: int(str(x)[-2:]))
df_avg_temp_Morton = df_avg_temp_Morton.drop(['Date'], axis=1)

# Testing (avg_temp)
#df_avg_temp_Haskell.head()

# %% [markdown]
# #### Min_Temp (minimum temperature)

# %%
# Grant (min_temp)
df_min_temp_Grant = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Grant_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Grant.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Grant['Year'] = df_min_temp_Grant['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Grant['Month'] = df_min_temp_Grant['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Grant = df_min_temp_Grant.drop(['Date'], axis=1)

# Gray (min_temp)
df_min_temp_Gray = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Gray_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Gray.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Gray['Year'] = df_min_temp_Gray['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Gray['Month'] = df_min_temp_Gray['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Gray = df_min_temp_Gray.drop(['Date'], axis=1)

# Haskell (min_temp)
df_min_temp_Haskell = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Haskell_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Haskell.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Haskell['Year'] = df_min_temp_Haskell['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Haskell['Month'] = df_min_temp_Haskell['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Haskell = df_min_temp_Haskell.drop(['Date'], axis=1)

# Kearny (min_temp)
df_min_temp_Kearny = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Kearny_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Kearny.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Kearny['Year'] = df_min_temp_Kearny['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Kearny['Month'] = df_min_temp_Kearny['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Kearny = df_min_temp_Kearny.drop(['Date'], axis=1)

# Morton (min_temp)
df_min_temp_Morton = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Morton_Min_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_min_temp_Morton.rename(columns={'Value':'Min_Temp'}, inplace=True)
df_min_temp_Morton['Year'] = df_min_temp_Morton['Date'].apply(lambda x: int(str(x)[:4]))
df_min_temp_Morton['Month'] = df_min_temp_Morton['Date'].apply(lambda x: int(str(x)[-2:]))
df_min_temp_Morton = df_min_temp_Morton.drop(['Date'], axis=1)

# Testing (min_temp)
#df_min_temp_Morton.head()

# %% [markdown]
# #### Max_Temp (maximum temperature)

# %%
# Grant (max_temp)
df_max_temp_Grant = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Grant_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Grant.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Grant['Year'] = df_max_temp_Grant['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Grant['Month'] = df_max_temp_Grant['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Grant = df_max_temp_Grant.drop(['Date'], axis=1)

# Gray (max_temp)
df_max_temp_Gray = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Gray_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Gray.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Gray['Year'] = df_max_temp_Gray['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Gray['Month'] = df_max_temp_Gray['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Gray = df_max_temp_Gray.drop(['Date'], axis=1)

# Haskell (max_temp)
df_max_temp_Haskell = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Haskell_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Haskell.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Haskell['Year'] = df_max_temp_Haskell['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Haskell['Month'] = df_max_temp_Haskell['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Haskell = df_max_temp_Haskell.drop(['Date'], axis=1)

# Kearny (max_temp)
df_max_temp_Kearny = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Kearny_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Kearny.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Kearny['Year'] = df_max_temp_Kearny['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Kearny['Month'] = df_max_temp_Kearny['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Kearny = df_max_temp_Kearny.drop(['Date'], axis=1)

# Morton (max_temp)
df_max_temp_Morton = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Morton_Max_Temp.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_max_temp_Morton.rename(columns={'Value':'Max_Temp'}, inplace=True)
df_max_temp_Morton['Year'] = df_max_temp_Morton['Date'].apply(lambda x: int(str(x)[:4]))
df_max_temp_Morton['Month'] = df_max_temp_Morton['Date'].apply(lambda x: int(str(x)[-2:]))
df_max_temp_Morton = df_max_temp_Morton.drop(['Date'], axis=1)

# Testing (max_temp)
#df_max_temp_Kearny.head()

# %% [markdown]
# #### Precipitation

# %%
# Grant (precipitation)
df_precipitation_Grant = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Grant_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Grant.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Grant['Year'] = df_precipitation_Grant['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Grant['Month'] = df_precipitation_Grant['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Grant = df_precipitation_Grant.drop(['Date'], axis=1)

# Gray (precipitation)
df_precipitation_Gray = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Gray_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Gray.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Gray['Year'] = df_precipitation_Gray['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Gray['Month'] = df_precipitation_Gray['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Gray = df_precipitation_Gray.drop(['Date'], axis=1)

# Haskell (precipitation)
df_precipitation_Haskell = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Haskell_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Haskell.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Haskell['Year'] = df_precipitation_Haskell['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Haskell['Month'] = df_precipitation_Haskell['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Haskell = df_precipitation_Haskell.drop(['Date'], axis=1)

# Kearny (precipitation)
df_precipitation_Kearny = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Kearny_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Kearny.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Kearny['Year'] = df_precipitation_Kearny['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Kearny['Month'] = df_precipitation_Kearny['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Kearny = df_precipitation_Kearny.drop(['Date'], axis=1)

# Morton (precipitation)
df_precipitation_Morton = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_Morton_Precipitation.csv", skiprows=4).drop(['Anomaly'], axis=1)
df_precipitation_Morton.rename(columns={'Value':'Precipitation'}, inplace=True)
df_precipitation_Morton['Year'] = df_precipitation_Morton['Date'].apply(lambda x: int(str(x)[:4]))
df_precipitation_Morton['Month'] = df_precipitation_Morton['Date'].apply(lambda x: int(str(x)[-2:]))
df_precipitation_Morton = df_precipitation_Morton.drop(['Date'], axis=1)

# Testing (precipitation)
#df_precipitation_Gray.head()

# %% [markdown]
# #### Drought (PDSI)

# %%
df_drought_KS = pd.read_csv("Data_KS_WA/KS/KS_Climate/KS_PDSI.csv", skiprows=3).drop(['Anomaly'], axis=1)
df_drought_KS.rename(columns={'Value':'PDSI'}, inplace=True)
df_drought_KS['Year'] = df_drought_KS['Date'].apply(lambda x: int(str(x)[:4]))
df_drought_KS['Month'] = df_drought_KS['Date'].apply(lambda x: int(str(x)[-2:]))
df_drought_KS = df_drought_KS.drop(['Date'], axis=1)

# Testing (drought)
#df_drought_KS.head()

# %% [markdown]
# #### Adding climate data to Cause_of_Loss datasets (by county for KS)

# %%
# Grant
df_loss_Grant = pd.read_csv("Data_KS_WA/KS/KS_Cause_of_Loss/KS_Grant_Cause_of_Loss.csv") 
df_loss_Grant.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Grant['Year'] = pd.to_numeric(df_loss_Grant['Year'], downcast='integer')
df_loss_Grant['Month'] = pd.to_numeric(df_loss_Grant['Month'], downcast='integer')
df_loss_Grant_merged = pd.merge(df_loss_Grant, df_avg_temp_Grant, how='left', on=['Year', 'Month'])
df_loss_Grant_merged = pd.merge(df_loss_Grant_merged, df_min_temp_Grant, how='left', on=['Year', 'Month'])
df_loss_Grant_merged = pd.merge(df_loss_Grant_merged, df_max_temp_Grant, how='left', on=['Year', 'Month'])
df_loss_Grant_merged = pd.merge(df_loss_Grant_merged, df_precipitation_Grant, how='left', on=['Year', 'Month'])
df_loss_Grant_merged = pd.merge(df_loss_Grant_merged, df_drought_KS, how='left', on=['Year', 'Month'])

# Gray
df_loss_Gray = pd.read_csv("Data_KS_WA/KS/KS_Cause_of_Loss/KS_Gray_Cause_of_Loss.csv") 
df_loss_Gray.Month.replace({"Unspecified": 0}, inplace=True) 
df_loss_Gray['Year'] = pd.to_numeric(df_loss_Gray['Year'], downcast='integer')
df_loss_Gray['Month'] = pd.to_numeric(df_loss_Gray['Month'], downcast='integer')
df_loss_Gray_merged = pd.merge(df_loss_Gray, df_avg_temp_Gray, how='left', on=['Year', 'Month'])
df_loss_Gray_merged = pd.merge(df_loss_Gray_merged, df_min_temp_Gray, how='left', on=['Year', 'Month'])
df_loss_Gray_merged = pd.merge(df_loss_Gray_merged, df_max_temp_Gray, how='left', on=['Year', 'Month'])
df_loss_Gray_merged = pd.merge(df_loss_Gray_merged, df_precipitation_Gray, how='left', on=['Year', 'Month'])
df_loss_Gray_merged = pd.merge(df_loss_Gray_merged, df_drought_KS, how='left', on=['Year', 'Month'])

# Haskell
df_loss_Haskell = pd.read_csv("Data_KS_WA/KS/KS_Cause_of_Loss/KS_Haskell_Cause_of_Loss.csv") 
df_loss_Haskell.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Haskell['Year'] = pd.to_numeric(df_loss_Haskell['Year'], downcast='integer')
df_loss_Haskell['Month'] = pd.to_numeric(df_loss_Haskell['Month'], downcast='integer')
df_loss_Haskell_merged = pd.merge(df_loss_Haskell, df_avg_temp_Haskell, how='left', on=['Year', 'Month'])
df_loss_Haskell_merged = pd.merge(df_loss_Haskell_merged, df_min_temp_Haskell, how='left', on=['Year', 'Month'])
df_loss_Haskell_merged = pd.merge(df_loss_Haskell_merged, df_max_temp_Haskell, how='left', on=['Year', 'Month'])
df_loss_Haskell_merged = pd.merge(df_loss_Haskell_merged, df_precipitation_Haskell, how='left', on=['Year', 'Month'])
df_loss_Haskell_merged = pd.merge(df_loss_Haskell_merged, df_drought_KS, how='left', on=['Year', 'Month'])

# Kearny
df_loss_Kearny = pd.read_csv("Data_KS_WA/KS/KS_Cause_of_Loss/KS_Kearny_Cause_of_Loss.csv") 
df_loss_Kearny.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Kearny['Year'] = pd.to_numeric(df_loss_Kearny['Year'], downcast='integer')
df_loss_Kearny['Month'] = pd.to_numeric(df_loss_Kearny['Month'], downcast='integer')
df_loss_Kearny_merged = pd.merge(df_loss_Kearny, df_avg_temp_Kearny, how='left', on=['Year', 'Month'])
df_loss_Kearny_merged = pd.merge(df_loss_Kearny_merged, df_min_temp_Kearny, how='left', on=['Year', 'Month'])
df_loss_Kearny_merged = pd.merge(df_loss_Kearny_merged, df_max_temp_Kearny, how='left', on=['Year', 'Month'])
df_loss_Kearny_merged = pd.merge(df_loss_Kearny_merged, df_precipitation_Kearny, how='left', on=['Year', 'Month'])
df_loss_Kearny_merged = pd.merge(df_loss_Kearny_merged, df_drought_KS, how='left', on=['Year', 'Month'])

# Morton
df_loss_Morton = pd.read_csv("Data_KS_WA/KS/KS_Cause_of_Loss/KS_Morton_Cause_of_Loss.csv") 
df_loss_Morton.Month.replace({"Unspecified": 0}, inplace=True)
df_loss_Morton['Year'] = pd.to_numeric(df_loss_Morton['Year'], downcast='integer')
df_loss_Morton['Month'] = pd.to_numeric(df_loss_Morton['Month'], downcast='integer')
df_loss_Morton_merged = pd.merge(df_loss_Morton, df_avg_temp_Morton, how='left', on=['Year', 'Month'])
df_loss_Morton_merged = pd.merge(df_loss_Morton_merged, df_min_temp_Morton, how='left', on=['Year', 'Month'])
df_loss_Morton_merged = pd.merge(df_loss_Morton_merged, df_max_temp_Morton, how='left', on=['Year', 'Month'])
df_loss_Morton_merged = pd.merge(df_loss_Morton_merged, df_precipitation_Morton, how='left', on=['Year', 'Month'])
df_loss_Morton_merged = pd.merge(df_loss_Morton_merged, df_drought_KS, how='left', on=['Year', 'Month'])

# Testing
df_loss_Grant_merged.head(10)
# Out:
#    State State name  County County name  Year  Month Commodity (partial list)  \
# 0     20     Kansas      67       Grant  1989      0                    Wheat
# 1     20     Kansas      67       Grant  1989      1                    Wheat
# 2     20     Kansas      67       Grant  1989      1                    Wheat
# 3     20     Kansas      67       Grant  1989      2                    Wheat
# 4     20     Kansas      67       Grant  1989      2                    Wheat
# 5     20     Kansas      67       Grant  1989      2                    Wheat
# 6     20     Kansas      67       Grant  1989      3                    Wheat
# 7     20     Kansas      67       Grant  1989      3                    Wheat
# 8     20     Kansas      67       Grant  1989      3                    Wheat
# 9     20     Kansas      67       Grant  1989      4                    Wheat
#
#       Cause of loss  Payment indemnity (US$)  Payment acreage  Payment count  \
# ...

# %% [markdown]
# #### Combining modified Cause_of_Loss datasets (all counties in KS)

# %%
frames_KS = [df_loss_Grant_merged, df_loss_Gray_merged, df_loss_Haskell_merged, df_loss_Kearny_merged, df_loss_Morton_merged]
df_loss_KS = pd.concat(frames_KS) # contains all KS counties
#print(df_loss_KS)

# %% [markdown]
# ## Plots
# Color palettes: https://python-graph-gallery.com/100-calling-a-color-with-seaborn/
# Plot types: https://seaborn.pydata.org/tutorial/regression.html
# Data distribution visuals: https://seaborn.pydata.org/generated/seaborn.jointplot.html
# Note — by default, shaded areas of the plot represent the 95% confidence interval for (the slope of) that regression

# %%
# Generate random colormap
def rand_cmap(nlabels, type='bright', first_color_black=False, last_color_black=False, verbose=False):
    """
    Creates a random colormap to be used together with matplotlib. Useful for segmentation tasks
    :param nlabels: Number of labels (size of colormap)
    :param type: 'bright' for strong colors, 'soft' for pastel colors
    :param first_color_black: Option to use first color as black, True or False
    :param last_color_black: Option to use last color as black, True or False
    :param verbose: Prints the number of labels and shows the colormap. True or False
    :return: colormap for matplotlib
    """
    from matplotlib.colors import LinearSegmentedColormap
    import colorsys
    import numpy as np

    if type not in ('bright', 'soft'):
        print ('Please choose "bright" or "soft" for type')
        return
    if verbose:
        print('Number of labels: ' + str(nlabels))

    # Generate color map for bright colors, based on hsv
    if type == 'bright':
        randHSVcolors = [(np.random.uniform(low=0.0, high=1),
                          np.random.uniform(low=0.2, high=1),
                          np.random.uniform(low=0.9, high=1)) for i in range(nlabels)]

        # Convert HSV list to RGB
        randRGBcolors = []
        for HSVcolor in randHSVcolors:
            randRGBcolors.append(colorsys.hsv_to_rgb(HSVcolor[0], HSVcolor[1], HSVcolor[2]))
        if first_color_black:
            randRGBcolors[0] = [0, 0, 0]
        if last_color_black:
            randRGBcolors[-1] = [0, 0, 0]
        random_colormap = LinearSegmentedColormap.from_list('new_map', randRGBcolors, N=nlabels)

    # Generate soft pastel colors, by limiting the RGB spectrum
    if type == 'soft':
        low = 0.6
        high = 0.95
        randRGBcolors = [(np.random.uniform(low=low, high=high),
                          np.random.uniform(low=low, high=high),
                          np.random.uniform(low=low, high=high)) for i in range(nlabels)]

        if first_color_black:
            randRGBcolors[0] = [0, 0, 0]
        if last_color_black:
            randRGBcolors[-1] = [0, 0, 0]
        random_colormap = LinearSegmentedColormap.from_list('new_map', randRGBcolors, N=nlabels)

    # Display colorbar
    if verbose:
        from matplotlib import colors, colorbar
        from matplotlib import pyplot as plt
        fig, ax = plt.subplots(1, 1, figsize=(15, 0.5))
        bounds = np.linspace(0, nlabels, nlabels + 1)
        norm = colors.BoundaryNorm(bounds, nlabels)
        cb = colorbar.ColorbarBase(ax, cmap=random_colormap, norm=norm, spacing='proportional', ticks=None,
                                   boundaries=bounds, format='%1i', orientation=u'horizontal')
        
    random_color_list = []
    for i in range(random_colormap.N):
        rgb = random_colormap(i)[:3] # will return rgba, we take only first 3 so we get rgb
        random_color_list.append(matplotlib.colors.rgb2hex(rgb))
    return random_color_list
    #return random_colormap

# %%
def generate_random_color_list(length):
    random_color_list = []
    for i in range(length):
        color = "#" + "%06x" % random.randint(0, 0xFFFFFF)
        random_color_list.append(color)
    return random_color_list

def generates_frequency_list(counties_list, dict_val_counts_state, list_dict_val_counts_county):
    frequency_list = []
    for key in dict_val_counts_state.keys():
        for dict_val_counts_county in list_dict_val_counts_county:
            frequency_list.append(dict_val_counts_county.get(key, 0))
    return frequency_list

# %% [markdown]
# ### Washington (WA)

# %%
df_loss_Lincoln_clean = df_loss_Lincoln_merged.copy().dropna()
df_loss_Okanogan_clean = df_loss_Okanogan_merged.copy().dropna()
df_loss_Skagit_clean = df_loss_Skagit_merged.copy().dropna()
df_loss_Spokane_clean = df_loss_Spokane_merged.copy().dropna()
df_loss_Whitman_clean = df_loss_Whitman_merged.copy().dropna()

df_loss_WA_clean = df_loss_WA.copy().dropna() # all counties

# %% [markdown]
# #### Cause of loss

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='Avg_Temp', data=df_loss_WA_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
violin_plot.set(ylabel='Average temperature')
plt.title('Average Temperature Distributions (WA)')
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='Precipitation', data=df_loss_WA_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
plt.title('Precipitation Distributions (WA)')
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='PDSI', data=df_loss_WA_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
plt.title('Drought Severity Distributions (WA)')
plt.show()

# %%
sns.set(font_scale=0.7)
sns.set_style("whitegrid")  

histogram = sns.countplot(y="Cause of loss", data=df_loss_WA_clean)
histogram.set(xlabel='Count')
plt.title('Cause of Loss Frequency (WA)')
plt.show()

# %%
# Types of causes of loss
causes_loss_WA = df_loss_WA_clean['Cause of loss'].unique()
num_causes_loss_WA = len(causes_loss_WA)
print(list(causes_loss_WA))
# Out:
# ['Cold Winter', 'Drought', 'Freeze', 'Frost', 'Flood', 'Other', 'Hail', 'Cold Wet Weather', 'Heat', 'Insects', 'Wind/excess Wind', 'Failure Of Irrigation Supply', 'Excess Moisture/precip/rain', 'Poor Drainage', 'Plant Disease', 'Erosion', 'Fire', 'Decline In Price', 'Wildlife', 'Hot Wind', 'Cyclone', 'Falling Numbers', 'No Indemnity', 'Failure Of Irrigation Equipment']

# %%
val_counts_Lincoln = df_loss_Lincoln_clean['Cause of loss'].value_counts()
val_counts_Okanogan = df_loss_Okanogan_clean['Cause of loss'].value_counts()
val_counts_Skagit = df_loss_Skagit_clean['Cause of loss'].value_counts()
val_counts_Spokane = df_loss_Spokane_clean['Cause of loss'].value_counts()
val_counts_Whitman = df_loss_Whitman_clean['Cause of loss'].value_counts()
val_counts_WA = df_loss_WA_clean['Cause of loss'].value_counts()

counties_list_WA = ['Lincoln', 'Okanogan', 'Skagit', 'Spokane', 'Whitman']
dict_val_counts_WA = dict(val_counts_WA)
list_dict_val_counts_county_WA = [dict(val_counts_Lincoln), dict(val_counts_Okanogan), dict(val_counts_Skagit), dict(val_counts_Spokane), dict(val_counts_Whitman)]

# Nested pie chart
labels = list(causes_loss_WA)
sizes = list(val_counts_WA)
labels_types = num_causes_loss_WA * counties_list_WA 
sizes_types = generates_frequency_list(counties_list_WA, dict_val_counts_WA, list_dict_val_counts_county_WA)
#colors = generate_random_color_list(num_causes_loss_WA)
#colors_types = num_causes_loss_WA * generate_random_color_list(len(counties_list_WA))
colors = rand_cmap(num_causes_loss_WA, type='soft')
colors_types = num_causes_loss_WA * rand_cmap(len(counties_list_WA), type='soft')
 
# Removing labels with insignificant counts
for i in range(len(labels)-1, 11, -1):
    labels[i] = ''
    
# County labels in inner ring
for i in range(len(labels_types)-1, 4, -1):
    labels_types[i] = ''
labels_types[2] = ''
labels_types[7] = 'Skagit'

plt.pie(sizes, labels=labels, colors=colors, startangle=90, frame=True, textprops={'fontsize': 7})
plt.pie(sizes_types, labels=labels_types, colors=colors_types, radius=0.7, startangle=90, textprops={'color':'white', 'fontsize':6})
centre_circle = plt.Circle((0,0), 0.25, color='black', fc='white', linewidth=0)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.rcParams['patch.linewidth'] = 0.25
plt.axis('equal')
plt.title('Causes of Loss (WA)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Climate
# Avg_Temp, Precipitation, PDSI over time, by county

# %%
# Average temperature
df_avg_temp_Lincoln['County'] = "Lincoln"
df_avg_temp_Okanogan['County'] = "Okanogan"
df_avg_temp_Skagit['County'] = "Skagit"
df_avg_temp_Spokane['County'] = "Spokane"
df_avg_temp_Whitman['County'] = "Whitman"
avg_temp_frames_WA = [df_avg_temp_Lincoln, df_avg_temp_Okanogan, df_avg_temp_Skagit, df_avg_temp_Spokane, df_avg_temp_Whitman]
df_avg_temp_WA = pd.concat(avg_temp_frames_WA) # contains all WA counties
df_avg_temp_WA['Month'] = df_avg_temp_WA.Month.map('{:02}'.format)
df_avg_temp_WA['Day'] = 1
df_avg_temp_WA['Date'] = pd.to_datetime(df_avg_temp_WA[['Year', 'Month', 'Day']])
df_avg_temp_WA['month_year'] = pd.to_datetime(df_avg_temp_WA['Date']).dt.to_period('M')
#df_avg_temp_WA.head(12)

# Precipitation
df_precipitation_Lincoln['County'] = "Lincoln"
df_precipitation_Okanogan['County'] = "Okanogan"
df_precipitation_Skagit['County'] = "Skagit"
df_precipitation_Spokane['County'] = "Spokane"
df_precipitation_Whitman['County'] = "Whitman"
precipitation_frames_WA = [df_precipitation_Lincoln, df_precipitation_Okanogan, df_precipitation_Skagit, df_precipitation_Spokane, df_precipitation_Whitman]
df_precipitation_WA = pd.concat(precipitation_frames_WA) # contains all WA counties
df_precipitation_WA['Month'] = df_precipitation_WA.Month.map('{:02}'.format)
df_precipitation_WA['Day'] = 1
df_precipitation_WA['Date'] = pd.to_datetime(df_precipitation_WA[['Year', 'Month', 'Day']])
df_precipitation_WA['month_year'] = pd.to_datetime(df_precipitation_WA['Date']).dt.to_period('M')

# Drought
df_drought_WA['Month'] = df_drought_WA.Month.map('{:02}'.format)
df_drought_WA['Day'] = 1
df_drought_WA['Date'] = pd.to_datetime(df_drought_WA[['Year', 'Month', 'Day']])
df_drought_WA['month_year'] = pd.to_datetime(df_drought_WA['Date']).dt.to_period('M')

# %%
sns.set(rc={"lines.linewidth": 1.0})
sns.set_style("whitegrid")

avg_temp_plot = sns.lineplot(data=df_avg_temp_WA, x='Date', y='Avg_Temp', hue='County', ci=None)
avg_temp_plot.set(xlabel='Time', ylabel='Average temperature')
avg_temp_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Average Temperature (WA)')
plt.show()

# %%
# Annual average temperature, by county

df_avg_temp_WA_annual = df_avg_temp_WA[['County', 'Date', 'Avg_Temp']]
df_avg_temp_Lincoln_annual, df_avg_temp_Okanogan_annual, df_avg_temp_Skagit_annual, df_avg_temp_Spokane_annual, df_avg_temp_Whitman_annual = [x for _, x in df_avg_temp_WA_annual.groupby(df_avg_temp_WA_annual['County'])]

# Lincoln
df_avg_temp_Lincoln_annual = df_avg_temp_Lincoln_annual.set_index('Date').resample('A').mean()
df_avg_temp_Lincoln_annual['County'] = 'Lincoln'
df_avg_temp_Lincoln_annual.reset_index(level=0, inplace=True)
df_avg_temp_Lincoln_annual['Year'] = df_avg_temp_Lincoln_annual['Date'].dt.year

# Okanogan
df_avg_temp_Okanogan_annual = df_avg_temp_Okanogan_annual.set_index('Date').resample('A').mean()
df_avg_temp_Okanogan_annual['County'] = 'Okanogan'
df_avg_temp_Okanogan_annual.reset_index(level=0, inplace=True)
df_avg_temp_Okanogan_annual['Year'] = df_avg_temp_Okanogan_annual['Date'].dt.year

# Skagit
df_avg_temp_Skagit_annual = df_avg_temp_Skagit_annual.set_index('Date').resample('A').mean()
df_avg_temp_Skagit_annual['County'] = 'Skagit'
df_avg_temp_Skagit_annual.reset_index(level=0, inplace=True)
df_avg_temp_Skagit_annual['Year'] = df_avg_temp_Skagit_annual['Date'].dt.year

# Spokane
df_avg_temp_Spokane_annual = df_avg_temp_Spokane_annual.set_index('Date').resample('A').mean()
df_avg_temp_Spokane_annual['County'] = 'Spokane'
df_avg_temp_Spokane_annual.reset_index(level=0, inplace=True)
df_avg_temp_Spokane_annual['Year'] = df_avg_temp_Spokane_annual['Date'].dt.year

# Whitman
df_avg_temp_Whitman_annual = df_avg_temp_Whitman_annual.set_index('Date').resample('A').mean()
df_avg_temp_Whitman_annual['County'] = 'Whitman'
df_avg_temp_Whitman_annual.reset_index(level=0, inplace=True)
df_avg_temp_Whitman_annual['Year'] = df_avg_temp_Whitman_annual['Date'].dt.year

df_avg_temp_WA_annual = pd.concat([df_avg_temp_Lincoln_annual, df_avg_temp_Okanogan_annual, df_avg_temp_Skagit_annual, df_avg_temp_Spokane_annual, df_avg_temp_Whitman_annual])
#df_avg_temp_WA_annual.head(60)

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.set(rc={'lines.markersize': 4.5, 'lines.linewidth': 0.75})
sns.set_style("white")
sns.set_style("ticks")

annual_avg_temp_plot = sns.lineplot(x='Year', y='Avg_Temp', data=df_avg_temp_Lincoln_annual, color='black', marker='o')
annual_avg_temp_plot.set(xlabel='Time', ylabel='Average temperature')

# Linear regression
x, y = df_avg_temp_Lincoln_annual['Year'].to_numpy(), df_avg_temp_Lincoln_annual['Avg_Temp'].to_numpy()
X, Y = x.reshape(-1,1), y.reshape(-1,1)
reg = LinearRegression().fit(X, Y)
print("R^2 value:", reg.score(X, Y))
print("m:", reg.coef_)
print("b:", reg.intercept_)

plt.plot(X, reg.predict(X))
plt.title('Average Temperature (Lincoln, WA)')
plt.show()
# Out:
# R^2 value: 3.1245490087483674e-06
# m: [[0.00023674]]
# b: [46.59690249]

# %%
sns.set(rc={'lines.markersize': 4.5, 'lines.linewidth': 0.75})
sns.set_style("white")
sns.set_style("ticks")

annual_avg_temp_plot = sns.lineplot(x='Year', y='Avg_Temp', data=df_avg_temp_Lincoln_annual, color='black', marker='o')
annual_avg_temp_plot.set(xlabel='Time', ylabel='Average temperature')

def polyfit(x, y, degree):
    results = {}
    coeffs = np.polyfit(x, y, degree)

    # Polynomial coefficients
    results['polynomial'] = coeffs.tolist()

    # r-squared
    p = np.poly1d(coeffs)
    # fit values, and mean
    yhat = p(x) # or [p(z) for z in x]
    ybar = np.sum(y)/len(y) # or sum(y)/len(y)
    ssreg = np.sum((yhat-ybar)**2) # or sum([ (yihat - ybar)**2 for yihat in yhat])
    sstot = np.sum((y - ybar)**2) # or sum([ (yi - ybar)**2 for yi in y])
    results['determination'] = ssreg / sstot
    return results

x, y = df_avg_temp_Lincoln_annual['Year'].to_numpy(), df_avg_temp_Lincoln_annual['Avg_Temp'].to_numpy()
#X, Y = x.reshape(-1,1), y.reshape(-1,1)
#print(polyfit(X, Y, 3))
results = polyfit(x, y, 1) # indicate polynomial degree
print(results)

coeffs = list(reversed(results['polynomial']))
y = np.array([np.sum(np.array([coeffs[i]*(j**i) for i in range(len(coeffs))])) for j in x])
plt.plot(x, y, 'r')
plt.show()
# Out:
# {'polynomial': [0.0002367424242424887, 46.59690249266847], 'determination': 3.124549008904033e-06}

# %%
sns.set(rc={"lines.linewidth": 1.0})
sns.set_style("whitegrid")
        
precipitation_plot = sns.lineplot(data=df_precipitation_WA, x='Date', y='Precipitation', hue='County', ci=None)
precipitation_plot.set(xlabel='Time', ylabel='Precipitation')
precipitation_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Precipitation (WA)')
plt.show()

# %%
sns.set(rc={"lines.linewidth": 1.25})
sns.set_style("whitegrid")

drought_plot = sns.lineplot(data=df_drought_WA, x='Date', y='PDSI', ci=None)
drought_plot.set(xlabel='Time', ylabel='PDSI')
drought_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Drought Severity (WA)')
plt.show()

# %% [markdown]
# ### Kansas (KS)

# %%
df_loss_Grant_clean = df_loss_Grant_merged.copy().dropna()
df_loss_Gray_clean = df_loss_Gray_merged.copy().dropna()
df_loss_Haskell_clean = df_loss_Haskell_merged.copy().dropna()
df_loss_Kearny_clean = df_loss_Kearny_merged.copy().dropna()
df_loss_Morton_clean = df_loss_Morton_merged.copy().dropna()

df_loss_KS_clean = df_loss_KS.copy().dropna() # all counties

# %% [markdown]
# #### Cause of loss

# %%
matplotlib.rcParams['figure.dpi'] = 150

# %%
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='Avg_Temp', data=df_loss_KS_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
violin_plot.set(ylabel='Average temperature')
plt.title('Average Temperature Distributions (KS)')
plt.show()

# %%
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='Precipitation', data=df_loss_KS_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
plt.title('Precipitation Distributions (KS)')
plt.show()

# %%
plt.figure(figsize=(12,5))
violin_plot = sns.violinplot(x='Cause of loss', y='PDSI', data=df_loss_KS_clean)
violin_plot.set_xticklabels(violin_plot.get_xticklabels(), rotation=40, horizontalalignment='right')
plt.title('Drought Severity Distributions (KS)')
plt.show()

# %%
sns.set(font_scale=0.7)
sns.set_style("whitegrid")  

histogram = sns.countplot(y="Cause of loss", data=df_loss_KS_clean)
histogram.set(xlabel='Count')
plt.title('Cause of Loss Frequency (KS)')
plt.show()

# %%
# Types of causes of loss
causes_loss_KS = df_loss_KS_clean['Cause of loss'].unique()
num_causes_loss_KS = len(causes_loss_KS)
print(list(causes_loss_KS))
# Out:
# ['Drought', 'Wind/excess Wind', 'Cold Winter', 'Freeze', 'Cold Wet Weather', 'Plant Disease', 'Other', 'Failure Of Irrigation Supply', 'Excess Moisture/precip/rain', 'Hail', 'Hot Wind', 'Frost', 'Heat', 'Flood', 'Decline In Price', 'Cyclone', 'Fire', 'Insects', 'Wildlife', 'Area Plan Crops Only', 'Poor Drainage', 'Erosion', 'Mycotoxin (aflatoxin)', 'Falling Numbers', 'Failure Of Irrigation Equipment', 'Tornado', 'Hurricane/tropical Depression']

# %%
val_counts_Grant = df_loss_Grant_clean['Cause of loss'].value_counts()
val_counts_Gray = df_loss_Gray_clean['Cause of loss'].value_counts()
val_counts_Haskell = df_loss_Haskell_clean['Cause of loss'].value_counts()
val_counts_Kearny = df_loss_Kearny_clean['Cause of loss'].value_counts()
val_counts_Morton = df_loss_Morton_clean['Cause of loss'].value_counts()
val_counts_KS = df_loss_KS_clean['Cause of loss'].value_counts()

counties_list_KS = ['Grant', 'Gray', 'Haskell', 'Kearny', 'Morton']
dict_val_counts_KS = dict(val_counts_KS)
list_dict_val_counts_county_KS = [dict(val_counts_Grant), dict(val_counts_Gray), dict(val_counts_Haskell), dict(val_counts_Kearny), dict(val_counts_Morton)]

# Nested pie chart
labels = list(causes_loss_KS)
sizes = list(val_counts_KS)
labels_types = num_causes_loss_KS * counties_list_KS 
sizes_types = generates_frequency_list(counties_list_KS, dict_val_counts_KS, list_dict_val_counts_county_KS)
#colors = generate_random_color_list(num_causes_loss_KS)
#colors_types = num_causes_loss_KS * generate_random_color_list(len(counties_list_KS))
colors = rand_cmap(num_causes_loss_KS, type='soft')
colors_types = num_causes_loss_KS * rand_cmap(len(counties_list_KS), type='soft')
 
# Removing labels with insignificant counts
for i in range(len(labels)-1, 11, -1):
    labels[i] = ''
    
# County labels in inner ring
for i in range(len(labels_types)-1, 4, -1):
    labels_types[i] = ''

plt.pie(sizes, labels=labels, colors=colors, startangle=90, frame=True, textprops={'fontsize': 7})
plt.pie(sizes_types, labels=labels_types, colors=colors_types, radius=0.7, startangle=90, textprops={'color':'white', 'fontsize':6})
centre_circle = plt.Circle((0,0), 0.25, color='black', fc='white', linewidth=0)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.rcParams['patch.linewidth'] = 0.25
plt.axis('equal')
plt.title('Causes of Loss (KS)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Climate
# Avg_Temp, Precipitation, PDSI over time, by county

# %%
# Average temperature
df_avg_temp_Grant['County'] = "Grant"
df_avg_temp_Gray['County'] = "Gray"
df_avg_temp_Haskell['County'] = "Haskell"
df_avg_temp_Kearny['County'] = "Kearny"
df_avg_temp_Morton['County'] = "Morton"
avg_temp_frames_KS = [df_avg_temp_Grant, df_avg_temp_Gray, df_avg_temp_Haskell, df_avg_temp_Kearny, df_avg_temp_Morton]
df_avg_temp_KS = pd.concat(avg_temp_frames_KS) # contains all KS counties
df_avg_temp_KS['Month'] = df_avg_temp_KS.Month.map('{:02}'.format)
df_avg_temp_KS['Day'] = 1
df_avg_temp_KS['Date'] = pd.to_datetime(df_avg_temp_KS[['Year', 'Month', 'Day']])
df_avg_temp_KS['month_year'] = pd.to_datetime(df_avg_temp_KS['Date']).dt.to_period('M')
#df_avg_temp_KS.head(12)

# Precipitation
df_precipitation_Grant['County'] = "Grant"
df_precipitation_Gray['County'] = "Gray"
df_precipitation_Haskell['County'] = "Haskell"
df_precipitation_Kearny['County'] = "Kearny"
df_precipitation_Morton['County'] = "Morton"
precipitation_frames_KS = [df_precipitation_Grant, df_precipitation_Gray, df_precipitation_Haskell, df_precipitation_Kearny, df_precipitation_Morton]
df_precipitation_KS = pd.concat(precipitation_frames_KS) # contains all KS counties
df_precipitation_KS['Month'] = df_precipitation_KS.Month.map('{:02}'.format)
df_precipitation_KS['Day'] = 1
df_precipitation_KS['Date'] = pd.to_datetime(df_precipitation_KS[['Year', 'Month', 'Day']])
df_precipitation_KS['month_year'] = pd.to_datetime(df_precipitation_KS['Date']).dt.to_period('M')

# Drought
df_drought_KS['Month'] = df_drought_KS.Month.map('{:02}'.format)
df_drought_KS['Day'] = 1
df_drought_KS['Date'] = pd.to_datetime(df_drought_KS[['Year', 'Month', 'Day']])
df_drought_KS['month_year'] = pd.to_datetime(df_drought_KS['Date']).dt.to_period('M')

# %%
sns.set(rc={"lines.linewidth": 1.0})
sns.set_style("whitegrid")

avg_temp_plot = sns.lineplot(data=df_avg_temp_KS, x='Date', y='Avg_Temp', hue='County', ci=None)
avg_temp_plot.set(xlabel='Time', ylabel='Average temperature')
avg_temp_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Average Temperature (KS)')
plt.show()

# %%
sns.set(rc={"lines.linewidth": 1.0})
sns.set_style("whitegrid")

precipitation_plot = sns.lineplot(data=df_precipitation_KS, x='Date', y='Precipitation', hue='County', ci=None)
precipitation_plot.set(xlabel='Time', ylabel='Precipitation')
precipitation_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Precipitation (KS)')
plt.show()

# %%
sns.set(rc={"lines.linewidth": 1.25})
sns.set_style("whitegrid")

drought_plot = sns.lineplot(data=df_drought_KS, x='Date', y='PDSI', ci=None)
drought_plot.set(xlabel='Time', ylabel='PDSI')
drought_plot.xaxis.set_major_locator(mdates.MonthLocator(bymonth=range(1,2), interval=1))
plt.xticks(fontsize=6, rotation=40)
plt.title('Drought Severity (KS)')
plt.show()
